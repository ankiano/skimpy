# %% [markdown]
# ## 1. Imports and settings

# %%
# data analysis and wrangling
import pandas as pd
import numpy as np

# visualization
import matplotlib.pyplot as plt 
import seaborn as sns

#ignore warnings
import warnings
warnings.filterwarnings('ignore')

pd.set_option('display.max_columns', None) # else pandas show not all columns

# %%
# https://github.com/ankiano/skimpy

from skimpy import Preprocessing
from skimpy import WoE
# feature exploration
from skimpy import plot_density
# model metrics
from skimpy import plot_model_summary
from skimpy import predict_with_threshold
# model benchmark
from skimpy import model_benchmark


# models
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC, LinearSVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.linear_model import Perceptron
from sklearn.linear_model import SGDClassifier
from sklearn.tree import DecisionTreeClassifier
from lightgbm import LGBMClassifier

# %%
pipeline = Preprocessing()
woe = WoE()

# %% [markdown]
# ## 2. Load training dataset

# %%
dataset = pd.read_csv('./data/train.csv')

# %% [markdown]
# ## 3. General data overview

# %% [markdown]
# Some random example of row data

# %%
dataset.sample(3)
# Out:
#       Age Attrition BusinessTravel  DailyRate              Department  \
# 1164   40        No  Travel_Rarely        448  Research & Development
# 908    33        No  Travel_Rarely        536                   Sales
# 1451   38        No  Travel_Rarely        345                   Sales
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# 1164                16          3  Life Sciences              1
# 908                 10          5      Marketing              1
# 1451                10          2  Life Sciences              1
#
#       EmployeeNumber  EnvironmentSatisfaction  Gender  HourlyRate  \
# 1164            1641                        3  Female          84
# 908             1268                        4    Male          82
# 1451            2041                        1  Female         100
#
#       JobInvolvement  JobLevel                 JobRole  JobSatisfaction  \
# 1164               3         3  Manufacturing Director                4
# 908                4         3         Sales Executive                3
# 1451               3         2         Sales Executive                4
#
#      MaritalStatus  MonthlyIncome  MonthlyRate  NumCompaniesWorked Over18  \
# 1164        Single           7945        19948                   6      Y
# 908       Divorced           8380        21708                   0      Y
# 1451       Married           5343         5982                   1      Y
#
#      OverTime  PercentSalaryHike  PerformanceRating  RelationshipSatisfaction  \
# 1164      Yes                 15                  3                         4
# 908       Yes                 14                  3                         4
# 1451       No                 11                  3                         3
#
#       StandardHours  StockOptionLevel  TotalWorkingYears  \
# 1164             80                 0                 18
# 908              80                 2                 10
# 1451             80                 1                 10
#
#       TrainingTimesLastYear  WorkLifeBalance  YearsAtCompany  \
# 1164                      2                2               4
# 908                       3                3               9
# 1451                      1                3              10
#
#       YearsInCurrentRole  YearsSinceLastPromotion  YearsWithCurrManager
# 1164                   2                        3                     3
# 908                    8                        0                     8
# 1451                   7                        1                     9

# %% [markdown]
# Missing value overview

# %%
dataset.isnull().sum().compress(lambda x: x>0)
# Out:
# Series([], dtype: int64)

# %%
dataset['Attrition'] = dataset['Attrition'].map({'Yes':1, 'No':0})

# %% [markdown]
# ## 4. Feature engeneering

# %% [markdown]
# ### 4.1. Target (Attrition)

# %%
y_true = dataset['Attrition']

# %% [markdown]
# Sample is more less balanced by target variable

# %% [markdown]
# ### 4.2. Age

# %%
plot_density(data=dataset, feature='Age', target='Attrition')

# %%
transform = lambda x: pd.cut(x, bins=[-np.inf,20,25,33,40,45,np.inf])
feature = transform(dataset['Age'])
woe.calculate(H = feature, A = y_true)
# Out:
# Attrition          Ā      А     P(Hi)   P(Hi|Ā)   P(Hi|A) posterior-odds  \
# Age
# (-inf, 20.0]    12.0   16.0  0.019048  0.009732  0.067511        6.93671
# (20.0, 25.0]    67.0   28.0  0.064626  0.054339  0.118143        2.17419
# (25.0, 33.0]   354.0   97.0  0.306803  0.287105  0.409283        1.42555
# (33.0, 40.0]   387.0   44.0  0.293197  0.313869  0.185654       0.591502
# (40.0, 45.0]   174.0   18.0  0.130612  0.141119  0.075949       0.538193
# (45.0, inf]    239.0   34.0  0.185714  0.193836  0.143460       0.740109
# total         1233.0  237.0  1.000000  1.000000  1.000000
#
# Attrition    weight-of-evidence  information-value conclusion
# Age
# (-inf, 20.0]            1.93683           0.111906     medium
# (20.0, 25.0]           0.776657           0.049554       weak
# (25.0, 33.0]           0.354559           0.043319       weak
# (33.0, 40.0]           -0.52509           0.067324       weak
# (40.0, 45.0]          -0.619538           0.040375       weak
# (45.0, inf]           -0.300958           0.015161    useless
# total                                     0.327640     strong

# %%
pipeline.add(step=Preprocessing.Step(
    input_var='Age',
    transformations=[
        transform,
        lambda x, w=woe.dict: x.astype('str').map(w), # replace by woe value
    ],
    output_var='age_bin_woe',
    info=woe.iv
))

# %% [markdown]
# ### 4.3. BusinessTravel

# %%
feature = dataset['BusinessTravel']
woe.calculate(H = feature, A = y_true, woe_sorted=True)
# Out:
# Attrition               Ā      А     P(Hi)   P(Hi|Ā)   P(Hi|A) posterior-odds  \
# BusinessTravel
# Non-Travel          138.0   12.0  0.102041  0.111922  0.050633       0.452394
# Travel_Rarely       887.0  156.0  0.709524  0.719384  0.658228       0.914989
# Travel_Frequently   208.0   69.0  0.188435  0.168694  0.291139        1.72584
# total              1233.0  237.0  1.000000  1.000000  1.000000
#
# Attrition         weight-of-evidence  information-value conclusion
# BusinessTravel
# Non-Travel                 -0.793202           0.048615       weak
# Travel_Rarely             -0.0888436           0.005433    useless
# Travel_Frequently           0.545714           0.066820       weak
# total                                          0.120868     medium

# %%
pipeline.add(step=Preprocessing.Step(
    input_var='BusinessTravel',
    transformations=[
        lambda x, w=woe.dict: x.astype('str').map(w), # replace by woe value
    ],
    output_var='business_travel_woe',
    info=woe.iv
))

# %% [markdown]
# ### 4.4. DailyRate

# %%
plot_density(data=dataset, feature='DailyRate', target='Attrition')

# %%
transform = lambda x: pd.cut(x, bins=[-np.inf,200,600,800,1000,1400,np.inf])
feature = transform(dataset['DailyRate'])
woe.calculate(H = feature, A = y_true)
# Out:
# Attrition              Ā      А     P(Hi)   P(Hi|Ā)   P(Hi|A) posterior-odds  \
# DailyRate
# (-inf, 200.0]       93.0   13.0  0.072109  0.075426  0.054852       0.727236
# (200.0, 600.0]     337.0   85.0  0.287075  0.273317  0.358650        1.31221
# (600.0, 800.0]     170.0   35.0  0.139456  0.137875  0.147679        1.07111
# (800.0, 1000.0]    181.0   33.0  0.145578  0.146796  0.139241       0.948528
# (1000.0, 1400.0]   373.0   56.0  0.291837  0.302514  0.236287       0.781077
# (1400.0, inf]       79.0   15.0  0.063946  0.064071  0.063291       0.987822
# total             1233.0  237.0  1.000000  1.000000  1.000000
#
# Attrition        weight-of-evidence  information-value conclusion
# DailyRate
# (-inf, 200.0]             -0.318505           0.006553    useless
# (200.0, 600.0]             0.271714           0.023186       weak
# (600.0, 800.0]             0.068695           0.000674    useless
# (800.0, 1000.0]          -0.0528441           0.000399    useless
# (1000.0, 1400.0]          -0.247081           0.016364    useless
# (1400.0, inf]            -0.0122523           0.000010    useless
# total                                         0.047185       weak

# %%
pipeline.add(step=Preprocessing.Step(
    input_var='DailyRate',
    transformations=[
        transform,
        lambda x, w=woe.dict: x.astype('str').map(w), # replace by woe value
    ],
    output_var='daily_rate_bin_woe',
    info=woe.iv
))

# %% [markdown]
# ### 4.5. Department

# %%
feature = dataset['Department']
woe.calculate(H = feature, A = y_true, woe_sorted=True)
# Out:
# Attrition                    Ā      А     P(Hi)   P(Hi|Ā)   P(Hi|A)  \
# Department
# Research & Development   828.0  133.0  0.653741  0.671533  0.561181
# Human Resources           51.0   12.0  0.042857  0.041363  0.050633
# Sales                    354.0   92.0  0.303401  0.287105  0.388186
# total                   1233.0  237.0  1.000000  1.000000  1.000000
#
# Attrition              posterior-odds weight-of-evidence  information-value  \
# Department
# Research & Development       0.835672          -0.179519           0.019810
# Human Resources               1.22413           0.202226           0.001875
# Sales                         1.35207           0.301637           0.030490
# total                                                              0.052175
#
# Attrition              conclusion
# Department
# Research & Development    useless
# Human Resources           useless
# Sales                        weak
# total                        weak

# %%
pipeline.add(step=Preprocessing.Step(
    input_var='Department',
    transformations=[
        lambda x, w=woe.dict: x.astype('str').map(w), # replace by woe value
    ],
    output_var='department_woe',
    info=woe.iv
))

# %% [markdown]
# ### 4.6. DistanceFromHome

# %%
plot_density(data=dataset, feature='DistanceFromHome', target='Attrition')

# %%
transform = lambda x: pd.cut(x, bins=[-np.inf,5,10,np.inf])
feature = transform(dataset['DistanceFromHome'])
woe.calculate(H = feature, A = y_true)
# Out:
# Attrition              Ā      А     P(Hi)   P(Hi|Ā)   P(Hi|A) posterior-odds  \
# DistanceFromHome
# (-inf, 5.0]        545.0   87.0  0.429932  0.442011  0.367089       0.830496
# (5.0, 10.0]        337.0   57.0  0.268027  0.273317  0.240506       0.879953
# (10.0, inf]        351.0   93.0  0.302041  0.284672  0.392405        1.37845
# total             1233.0  237.0  1.000000  1.000000  1.000000
#
# Attrition        weight-of-evidence  information-value conclusion
# DistanceFromHome
# (-inf, 5.0]               -0.185732           0.013916    useless
# (5.0, 10.0]               -0.127886           0.004196    useless
# (10.0, inf]                0.320959           0.034578       weak
# total                                         0.052690       weak

# %%
pipeline.add(step=Preprocessing.Step(
    input_var='DistanceFromHome',
    transformations=[
        transform,
        lambda x, w=woe.dict: x.astype('str').map(w), # replace by woe value
    ],
    output_var='distance_from_home_bin_woe',
    info=woe.iv
))

# %% [markdown]
# ### 4.7. Education

# %%
feature = dataset['Education']
woe.calculate(H = feature, A = y_true)
# Out:
# Attrition       Ā      А     P(Hi)   P(Hi|Ā)   P(Hi|A) posterior-odds  \
# Education
# 1           139.0   31.0  0.115646  0.112733  0.130802        1.16028
# 2           238.0   44.0  0.191837  0.193025  0.185654       0.961813
# 3           473.0   99.0  0.389116  0.383617  0.417722         1.0889
# 4           340.0   58.0  0.270748  0.275750  0.244726       0.887491
# 5            43.0    5.0  0.032653  0.034874  0.021097       0.604946
# total      1233.0  237.0  1.000000  1.000000  1.000000
#
# Attrition weight-of-evidence  information-value conclusion
# Education
# 1                   0.148659           0.002686    useless
# 2                 -0.0389357           0.000287    useless
# 3                  0.0851698           0.002905    useless
# 4                  -0.119357           0.003703    useless
# 5                  -0.502617           0.006925    useless
# total                                  0.016505    useless

# %%
pipeline.add(step=Preprocessing.Step(
    input_var='Education',
    transformations=[
        lambda x, w=woe.dict: x.astype('str').map(w), # replace by woe value
    ],
    output_var='education_woe',
    info=woe.iv
))

# %% [markdown]
# ### 4.8. EducationField

# %%
feature = dataset['EducationField']
woe.calculate(H = feature, A = y_true)
# Out:
# Attrition              Ā      А     P(Hi)   P(Hi|Ā)   P(Hi|A) posterior-odds  \
# EducationField
# Human Resources     20.0    7.0  0.018367  0.016221  0.029536        1.82089
# Life Sciences      517.0   89.0  0.412245  0.419303  0.375527         0.8956
# Marketing          124.0   35.0  0.108163  0.100568  0.147679        1.46846
# Medical            401.0   63.0  0.315646  0.325223  0.265823       0.817355
# Other               71.0   11.0  0.055782  0.057583  0.046414       0.806026
# Technical Degree   100.0   32.0  0.089796  0.081103  0.135021        1.66481
# total             1233.0  237.0  1.000000  1.000000  1.000000
#
# Attrition        weight-of-evidence  information-value conclusion
# EducationField
# Human Resources            0.599323           0.007980    useless
# Life Sciences             -0.110261           0.004827    useless
# Marketing                  0.384212           0.018101    useless
# Medical                   -0.201681           0.011980    useless
# Other                     -0.215639           0.002409    useless
# Technical Degree           0.509711           0.027483       weak
# total                                         0.072779       weak

# %%
pipeline.add(step=Preprocessing.Step(
    input_var='EducationField',
    transformations=[
        lambda x, w=woe.dict: x.astype('str').map(w), # replace by woe value
    ],
    output_var='education_field_woe',
    info=woe.iv
))

# %% [markdown]
# ### 4.9. EmployeeCount

# %%
feature = dataset['EmployeeCount']
woe.calculate(H = feature, A = y_true)
# Out:
# Attrition           Ā      А  P(Hi)  P(Hi|Ā)  P(Hi|A) posterior-odds  \
# EmployeeCount
# 1              1233.0  237.0    1.0      1.0      1.0              1
# total          1233.0  237.0    1.0      1.0      1.0
#
# Attrition     weight-of-evidence  information-value conclusion
# EmployeeCount
# 1                              0                0.0    useless
# total                                           0.0    useless

# %% [markdown]
# ### 4.10. EmployeeNumber

# %%
plot_density(data=dataset, feature='EmployeeNumber', target='Attrition')

# %%
transform = lambda x: pd.cut(x, bins=[-np.inf,600,1400,np.inf])
feature = transform(dataset['EmployeeNumber'])
woe.calculate(H = feature, A = y_true)
# Out:
# Attrition             Ā      А     P(Hi)   P(Hi|Ā)   P(Hi|A) posterior-odds  \
# EmployeeNumber
# (-inf, 600.0]     378.0   70.0  0.304762  0.306569  0.295359       0.963432
# (600.0, 1400.0]   450.0   96.0  0.371429  0.364964  0.405063        1.10987
# (1400.0, inf]     405.0   71.0  0.323810  0.328467  0.299578       0.912049
# total            1233.0  237.0  1.000000  1.000000  1.000000
#
# Attrition       weight-of-evidence  information-value conclusion
# EmployeeNumber
# (-inf, 600.0]           -0.0372536           0.000418    useless
# (600.0, 1400.0]           0.104246           0.004180    useless
# (1400.0, inf]           -0.0920618           0.002660    useless
# total                                        0.007257    useless

# %%
pipeline.add(Preprocessing.Step(
    input_var='EmployeeNumber',
    transformations=[
        transform, 
        lambda x, w=woe.dict: x.astype('str').map(w), # replace by woe value
    ],
    output_var='employee_number_bin_woe',
    info=woe.iv
))

# %% [markdown]
# ### 4.11. EnvironmentSatisfaction

# %%
feature = dataset['EnvironmentSatisfaction']
woe.calculate(H = feature, A = y_true)
# Out:
# Attrition                     Ā      А     P(Hi)   P(Hi|Ā)   P(Hi|A)  \
# EnvironmentSatisfaction
# 1                         212.0   72.0  0.193197  0.171938  0.303797
# 2                         244.0   43.0  0.195238  0.197891  0.181435
# 3                         391.0   62.0  0.308163  0.317113  0.261603
# 4                         386.0   60.0  0.303401  0.313058  0.253165
# total                    1233.0  237.0  1.000000  1.000000  1.000000
#
# Attrition               posterior-odds weight-of-evidence  information-value  \
# EnvironmentSatisfaction
# 1                               1.7669           0.569225           0.075058
# 2                              0.91684         -0.0868227           0.001429
# 3                             0.824954          -0.192428           0.010682
# 4                             0.808684          -0.212347           0.012718
# total                                                               0.099886
#
# Attrition               conclusion
# EnvironmentSatisfaction
# 1                             weak
# 2                          useless
# 3                          useless
# 4                          useless
# total                         weak

# %%
pipeline.add(Preprocessing.Step(
    input_var='EnvironmentSatisfaction',
    transformations=[
        lambda x, w=woe.dict: x.astype('str').map(w), # replace by woe value
    ],
    output_var='enviroment_satisfaction_woe',
    info=woe.iv
))

# %% [markdown]
# ### 4.12. Gender

# %%
feature = dataset['Gender']
woe.calculate(H = feature, A = y_true)
# Out:
# Attrition       Ā      А  P(Hi)   P(Hi|Ā)   P(Hi|A) posterior-odds  \
# Gender
# Female      501.0   87.0    0.4  0.406326  0.367089       0.903434
# Male        732.0  150.0    0.6  0.593674  0.632911        1.06609
# total      1233.0  237.0    1.0  1.000000  1.000000
#
# Attrition weight-of-evidence  information-value conclusion
# Gender
# Female             -0.101553           0.003985    useless
# Male               0.0640001           0.002511    useless
# total                                  0.006496    useless

# %%
pipeline.add(Preprocessing.Step(
    input_var='Gender',
    transformations=[
        lambda x, w=woe.dict: x.astype('str').map(w), # replace by woe value
    ],
    output_var='gender_woe',
    info=woe.iv
))

# %% [markdown]
# ### 4.13. HourlyRate

# %%
plot_density(data=dataset, feature='HourlyRate', target='Attrition')

# %%
transform = lambda x: pd.cut(x, bins=[-np.inf,46,73,np.inf])
feature = transform(dataset['HourlyRate'])
woe.calculate(H = feature, A = y_true)
# Out:
# Attrition          Ā      А     P(Hi)   P(Hi|Ā)   P(Hi|A) posterior-odds  \
# HourlyRate
# (-inf, 46.0]   281.0   50.0  0.225170  0.227899  0.210970       0.925717
# (46.0, 73.0]   450.0  103.0  0.376190  0.364964  0.434599         1.1908
# (73.0, inf]    502.0   84.0  0.398639  0.407137  0.354430       0.870543
# total         1233.0  237.0  1.000000  1.000000  1.000000
#
# Attrition    weight-of-evidence  information-value conclusion
# HourlyRate
# (-inf, 46.0]         -0.0771863           0.001307    useless
# (46.0, 73.0]           0.174627           0.012160    useless
# (73.0, inf]           -0.138638           0.007307    useless
# total                                     0.020774       weak

# %%
pipeline.add(Preprocessing.Step(
    input_var='HourlyRate',
    transformations=[
        transform,
        lambda x, w=woe.dict: x.astype('str').map(w), # replace by woe value
    ],
    output_var='hourly_rate_bin_woe',
    info=woe.iv
))

# %% [markdown]
# ### 4.14. JobInvolvement

# %%
feature = dataset['JobInvolvement']
woe.calculate(H = feature, A = y_true)
# Out:
# Attrition            Ā      А     P(Hi)   P(Hi|Ā)   P(Hi|A) posterior-odds  \
# JobInvolvement
# 1                 55.0   28.0  0.056463  0.044607  0.118143        2.64856
# 2                304.0   71.0  0.255102  0.246553  0.299578        1.21506
# 3                743.0  125.0  0.590476  0.602595  0.527426       0.875258
# 4                131.0   13.0  0.097959  0.106245  0.054852       0.516282
# total           1233.0  237.0  1.000000  1.000000  1.000000
#
# Attrition      weight-of-evidence  information-value conclusion
# JobInvolvement
# 1                        0.974017           0.071626       weak
# 2                        0.194798           0.010329    useless
# 3                       -0.133237           0.010015    useless
# 4                       -0.661103           0.033976       weak
# total                                       0.125946     medium

# %%
pipeline.add(Preprocessing.Step(
    input_var='JobInvolvement',
    transformations=[
        lambda x, w=woe.dict: x.astype('str').map(w), # replace by woe value
    ],
    output_var='job_involment_woe',
    info=woe.iv
))

# %% [markdown]
# ### 4.15. JobRole

# %%
feature = dataset['JobRole']
woe.calculate(H = feature, A = y_true, woe_sorted=True)
# Out:
# Attrition                       Ā      А     P(Hi)   P(Hi|Ā)   P(Hi|A)  \
# JobRole
# Research Director            78.0    2.0  0.054422  0.063260  0.008439
# Manager                      97.0    5.0  0.069388  0.078670  0.021097
# Healthcare Representative   122.0    9.0  0.089116  0.098946  0.037975
# Manufacturing Director      135.0   10.0  0.098639  0.109489  0.042194
# Research Scientist          245.0   47.0  0.198639  0.198702  0.198312
# Sales Executive             269.0   57.0  0.221769  0.218167  0.240506
# Human Resources              40.0   12.0  0.035374  0.032441  0.050633
# Laboratory Technician       197.0   62.0  0.176190  0.159773  0.261603
# Sales Representative         50.0   33.0  0.056463  0.040552  0.139241
# total                      1233.0  237.0  1.000000  1.000000  1.000000
#
# Attrition                 posterior-odds weight-of-evidence  \
# JobRole
# Research Director               0.133398           -2.01442
# Manager                         0.268172           -1.31613
# Healthcare Representative       0.383793          -0.957651
# Manufacturing Director          0.385373          -0.953544
# Research Scientist              0.998037        -0.00196525
# Sales Executive                   1.1024          0.0974853
# Human Resources                  1.56076           0.445173
# Laboratory Technician            1.63734           0.493076
# Sales Representative             3.43367            1.23363
# total
#
# Attrition                  information-value conclusion
# JobRole
# Research Director               1.104334e-01     medium
# Manager                         7.577324e-02       weak
# Healthcare Representative       5.838892e-02       weak
# Manufacturing Director          6.416873e-02       weak
# Research Scientist              7.666736e-07    useless
# Sales Executive                 2.177748e-03    useless
# Human Resources                 8.098451e-03    useless
# Laboratory Technician           5.021016e-02       weak
# Sales Representative            1.217457e-01     medium
# total                           4.909971e-01     strong

# %%
pipeline.add(Preprocessing.Step(
    input_var='JobRole',
    transformations=[
        lambda x, w=woe.dict: x.astype('str').map(w), # replace by woe value
    ],
    output_var='job_role_woe',
    info=woe.iv
))

# %% [markdown]
# ### 4.16. JobSatisfaction

# %%
feature = dataset['JobSatisfaction']
woe.calculate(H = feature, A = y_true)
# Out:
# Attrition             Ā      А     P(Hi)   P(Hi|Ā)   P(Hi|A) posterior-odds  \
# JobSatisfaction
# 1                 223.0   66.0  0.196599  0.180860  0.278481        1.53976
# 2                 234.0   46.0  0.190476  0.189781  0.194093        1.02272
# 3                 369.0   73.0  0.300680  0.299270  0.308017        1.02923
# 4                 407.0   52.0  0.312245  0.330089  0.219409       0.664697
# total            1233.0  237.0  1.000000  1.000000  1.000000
#
# Attrition       weight-of-evidence  information-value conclusion
# JobSatisfaction
# 1                         0.431628           0.042136       weak
# 2                        0.0224656           0.000097    useless
# 3                        0.0288082           0.000252    useless
# 4                        -0.408424           0.045204       weak
# total                                        0.087689       weak

# %%
pipeline.add(Preprocessing.Step(
    input_var='JobSatisfaction',
    transformations=[
        lambda x, w=woe.dict: x.astype('str').map(w), # replace by woe value
    ],
    output_var='job_satisfaction_woe',
    info=woe.iv
))

# %% [markdown]
# ### 4.17. MaritalStatus

# %%
feature = dataset['MaritalStatus']
woe.calculate(H = feature, A = y_true)
# Out:
# Attrition           Ā      А     P(Hi)   P(Hi|Ā)   P(Hi|A) posterior-odds  \
# MaritalStatus
# Divorced        294.0   33.0  0.222449  0.238443  0.139241       0.583958
# Married         589.0   84.0  0.457823  0.477697  0.354430       0.741957
# Single          350.0  120.0  0.319728  0.283861  0.506329        1.78373
# total          1233.0  237.0  1.000000  1.000000  1.000000
#
# Attrition     weight-of-evidence  information-value conclusion
# MaritalStatus
# Divorced               -0.537927           0.053364       weak
# Married                -0.298464           0.036791       weak
# Single                  0.578704           0.128743     medium
# total                                      0.218898     medium

# %%
pipeline.add(Preprocessing.Step(
    input_var='MaritalStatus',
    transformations=[
        lambda x, w=woe.dict: x.astype('str').map(w), # replace by woe value
    ],
    output_var='marital_status_woe',
    info=woe.iv
))

# %% [markdown]
# ### 4.18. MonthlyIncome

# %%
plot_density(data=dataset, feature='MonthlyIncome', target='Attrition')

# %%
transform = lambda x: pd.cut(x, bins=[-np.inf,3500,9000,12000,np.inf])
feature = transform(dataset['MonthlyIncome'])
woe.calculate(H = feature, A = y_true)
# Out:
# Attrition               Ā      А     P(Hi)   P(Hi|Ā)   P(Hi|A) posterior-odds  \
# MonthlyIncome
# (-inf, 3500.0]      345.0  128.0  0.321769  0.279805  0.540084        1.93021
# (3500.0, 9000.0]    589.0   75.0  0.451701  0.477697  0.316456       0.662462
# (9000.0, 12000.0]   115.0   23.0  0.093878  0.093268  0.097046        1.04051
# (12000.0, inf]      184.0   11.0  0.132653  0.149230  0.046414       0.311021
# total              1233.0  237.0  1.000000  1.000000  1.000000
#
# Attrition         weight-of-evidence  information-value conclusion
# MonthlyIncome
# (-inf, 3500.0]              0.657631           0.171168     medium
# (3500.0, 9000.0]           -0.411793           0.066398       weak
# (9000.0, 12000.0]          0.0397074           0.000150    useless
# (12000.0, inf]               -1.1679           0.120078     medium
# total                                          0.357794     strong

# %%
pipeline.add(Preprocessing.Step(
    input_var='MonthlyIncome',
    transformations=[
        transform,
        lambda x, w=woe.dict: x.astype('str').map(w), # replace by woe value
    ],
    output_var='monthly_income_bin_woe',
    info=woe.iv
))

# %% [markdown]
# ### 4.19. MonthlyRate

# %%
plot_density(data=dataset, feature='MonthlyRate', target='Attrition')

# %%
transform = lambda x: pd.cut(x, bins=[-np.inf,9000,16000,24000,np.inf])
feature = transform(dataset['MonthlyRate'])
woe.calculate(H = feature, A = y_true)
# Out:
# Attrition                Ā      А     P(Hi)   P(Hi|Ā)   P(Hi|A)  \
# MonthlyRate
# (-inf, 9000.0]       360.0   61.0  0.286395  0.291971  0.257384
# (9000.0, 16000.0]    342.0   72.0  0.281633  0.277372  0.303797
# (16000.0, 24000.0]   410.0   77.0  0.331293  0.332522  0.324895
# (24000.0, inf]       121.0   27.0  0.100680  0.098135  0.113924
# total               1233.0  237.0  1.000000  1.000000  1.000000
#
# Attrition          posterior-odds weight-of-evidence  information-value  \
# MonthlyRate
# (-inf, 9000.0]            0.88154          -0.126085           0.004361
# (9000.0, 16000.0]         1.09527          0.0910007           0.002405
# (16000.0, 24000.0]       0.977061         -0.0232064           0.000177
# (24000.0, inf]             1.1609           0.149192           0.002356
# total                                                          0.009298
#
# Attrition          conclusion
# MonthlyRate
# (-inf, 9000.0]        useless
# (9000.0, 16000.0]     useless
# (16000.0, 24000.0]    useless
# (24000.0, inf]        useless
# total                 useless

# %%
pipeline.add(Preprocessing.Step(
    input_var='MonthlyRate',
    transformations=[
        transform,
        lambda x, w=woe.dict: x.astype('str').map(w), # replace by woe value
    ],
    output_var='monthly_rate_bin_woe',
    info=woe.iv
))

# %% [markdown]
# ### 4.20. NumCompaniesWorked

# %%
feature = dataset['NumCompaniesWorked']
woe.calculate(H = feature, A = y_true)
# Out:
# Attrition                Ā      А     P(Hi)   P(Hi|Ā)   P(Hi|A)  \
# NumCompaniesWorked
# 0                    174.0   23.0  0.134014  0.141119  0.097046
# 1                    423.0   98.0  0.354422  0.343066  0.413502
# 2                    130.0   16.0  0.099320  0.105434  0.067511
# 3                    143.0   16.0  0.108163  0.115977  0.067511
# 4                    122.0   17.0  0.094558  0.098946  0.071730
# 5                     47.0   16.0  0.042857  0.038118  0.067511
# 6                     54.0   16.0  0.047619  0.043796  0.067511
# 7                     57.0   17.0  0.050340  0.046229  0.071730
# 8                     43.0    6.0  0.033333  0.034874  0.025316
# 9                     40.0   12.0  0.035374  0.032441  0.050633
# total               1233.0  237.0  1.000000  1.000000  1.000000
#
# Attrition          posterior-odds weight-of-evidence  information-value  \
# NumCompaniesWorked
# 0                        0.687691          -0.374416           0.016502
# 1                         1.20531           0.186741           0.013153
# 2                        0.640312            -0.4458           0.016906
# 3                        0.582101          -0.541111           0.026226
# 4                        0.724943          -0.321662           0.008754
# 5                         1.77107           0.571586           0.016800
# 6                         1.54149            0.43275           0.010263
# 7                         1.55163           0.439307           0.011203
# 8                        0.725935          -0.320295           0.003061
# 9                         1.56076           0.445173           0.008098
# total                                                          0.130967
#
# Attrition          conclusion
# NumCompaniesWorked
# 0                     useless
# 1                     useless
# 2                     useless
# 3                        weak
# 4                     useless
# 5                     useless
# 6                     useless
# 7                     useless
# 8                     useless
# 9                     useless
# total                  medium

# %%
pipeline.add(Preprocessing.Step(
    input_var='NumCompaniesWorked',
    transformations=[
        lambda x, w=woe.dict: x.astype('str').map(w), # replace by woe value
    ],
    output_var='num_companies_worked_woe',
    info=woe.iv
))

# %% [markdown]
# ### 4.21. Over18

# %%
feature = dataset['Over18']
woe.calculate(H = feature, A = y_true)
# Out:
# Attrition       Ā      А  P(Hi)  P(Hi|Ā)  P(Hi|A) posterior-odds  \
# Over18
# Y          1233.0  237.0    1.0      1.0      1.0              1
# total      1233.0  237.0    1.0      1.0      1.0
#
# Attrition weight-of-evidence  information-value conclusion
# Over18
# Y                          0                0.0    useless
# total                                       0.0    useless

# %% [markdown]
# ### 4.22. OverTime

# %%
feature = dataset['OverTime']
woe.calculate(H = feature, A = y_true)
# Out:
# Attrition       Ā      А     P(Hi)   P(Hi|Ā)   P(Hi|A) posterior-odds  \
# OverTime
# No          944.0  110.0  0.717007  0.765612  0.464135       0.606227
# Yes         289.0  127.0  0.282993  0.234388  0.535865        2.28623
# total      1233.0  237.0  1.000000  1.000000  1.000000
#
# Attrition weight-of-evidence  information-value conclusion
# OverTime
# No                   -0.5005           0.150890     medium
# Yes                 0.826906           0.249293     medium
# total                                  0.400183     strong

# %%
pipeline.add(Preprocessing.Step(
    input_var='OverTime',
    transformations=[
        lambda x, w=woe.dict: x.astype('str').map(w), # replace by woe value
    ],
    output_var='overtime_woe',
    info=woe.iv
))

# %% [markdown]
# ### 4.23. PercentSalaryHike

# %%
plot_density(data=dataset, feature='PercentSalaryHike', target='Attrition')

# %%
transform = lambda x: pd.cut(x, bins=[-np.inf,12,15,17,22,np.inf])
feature = transform(dataset['PercentSalaryHike'])
woe.calculate(H = feature, A = y_true)
# Out:
# Attrition               Ā      А     P(Hi)   P(Hi|Ā)   P(Hi|A) posterior-odds  \
# PercentSalaryHike
# (-inf, 12.0]        334.0   74.0  0.277551  0.270884  0.312236        1.15266
# (12.0, 15.0]        435.0   76.0  0.347619  0.352798  0.320675       0.908948
# (15.0, 17.0]        132.0   28.0  0.108844  0.107056  0.118143        1.10357
# (17.0, 22.0]        278.0   46.0  0.220408  0.225466  0.194093       0.860851
# (22.0, inf]          54.0   13.0  0.045578  0.043796  0.054852        1.25246
# total              1233.0  237.0  1.000000  1.000000  1.000000
#
# Attrition         weight-of-evidence  information-value conclusion
# PercentSalaryHike
# (-inf, 12.0]                0.142069           0.005875    useless
# (12.0, 15.0]              -0.0954673           0.003067    useless
# (15.0, 17.0]               0.0985479           0.001093    useless
# (17.0, 22.0]               -0.149834           0.004701    useless
# (22.0, inf]                 0.225111           0.002489    useless
# total                                          0.017224    useless

# %%
pipeline.add(Preprocessing.Step(
    input_var='PercentSalaryHike',
    transformations=[
        transform,
        lambda x, w=woe.dict: x.astype('str').map(w), # replace by woe value
    ],
    output_var='percent_salary_hike_bin_woe',
    info=woe.iv
))

# %% [markdown]
# ### 4.24. PerformanceRating

# %%
feature = dataset['PerformanceRating']
woe.calculate(H = feature, A = y_true)
# Out:
# Attrition               Ā      А     P(Hi)   P(Hi|Ā)   P(Hi|A) posterior-odds  \
# PerformanceRating
# 3                  1044.0  200.0  0.846259  0.846715  0.843882       0.996654
# 4                   189.0   37.0  0.153741  0.153285  0.156118        1.01849
# total              1233.0  237.0  1.000000  1.000000  1.000000
#
# Attrition         weight-of-evidence  information-value conclusion
# PerformanceRating
# 3                        -0.00335204           0.000009    useless
# 4                          0.0183163           0.000052    useless
# total                                          0.000061    useless

# %% [markdown]
# ### 4.25. RelationshipSatisfaction

# %%
feature = dataset['RelationshipSatisfaction']
woe.calculate(H = feature, A = y_true)
# Out:
# Attrition                      Ā      А     P(Hi)   P(Hi|Ā)   P(Hi|A)  \
# RelationshipSatisfaction
# 1                          219.0   57.0  0.187755  0.177616  0.240506
# 2                          258.0   45.0  0.206122  0.209246  0.189873
# 3                          388.0   71.0  0.312245  0.314680  0.299578
# 4                          368.0   64.0  0.293878  0.298459  0.270042
# total                     1233.0  237.0  1.000000  1.000000  1.000000
#
# Attrition                posterior-odds weight-of-evidence  information-value  \
# RelationshipSatisfaction
# 1                               1.35408           0.303125           0.019064
# 2                              0.907418         -0.0971517           0.001882
# 3                               0.95201         -0.0491801           0.000743
# 4                              0.904788          -0.100054           0.002843
# total                                                                0.024532
#
# Attrition                conclusion
# RelationshipSatisfaction
# 1                           useless
# 2                           useless
# 3                           useless
# 4                           useless
# total                          weak

# %%
pipeline.add(Preprocessing.Step(
    input_var='RelationshipSatisfaction',
    transformations=[
        lambda x, w=woe.dict: x.astype('str').map(w), # replace by woe value
    ],
    output_var='relationship_satisfaction_woe',
    info=woe.iv
))

# %% [markdown]
# ### 4.26. StandardHours

# %%
feature = dataset['StandardHours']
woe.calculate(H = feature, A = y_true)
# Out:
# Attrition           Ā      А  P(Hi)  P(Hi|Ā)  P(Hi|A) posterior-odds  \
# StandardHours
# 80             1233.0  237.0    1.0      1.0      1.0              1
# total          1233.0  237.0    1.0      1.0      1.0
#
# Attrition     weight-of-evidence  information-value conclusion
# StandardHours
# 80                             0                0.0    useless
# total                                           0.0    useless

# %% [markdown]
# ### 4.27. StockOptionLevel

# %%
feature = dataset['StockOptionLevel']
woe.calculate(H = feature, A = y_true)
# Out:
# Attrition              Ā      А     P(Hi)   P(Hi|Ā)   P(Hi|A) posterior-odds  \
# StockOptionLevel
# 0                  477.0  154.0  0.429252  0.386861  0.649789        1.67964
# 1                  540.0   56.0  0.405442  0.437956  0.236287       0.539522
# 2                  146.0   12.0  0.107483  0.118410  0.050633       0.427605
# 3                   70.0   15.0  0.057823  0.056772  0.063291        1.11483
# total             1233.0  237.0  1.000000  1.000000  1.000000
#
# Attrition        weight-of-evidence  information-value conclusion
# StockOptionLevel
# 0                          0.518581           0.136349     medium
# 1                         -0.617072           0.124444     medium
# 2                         -0.849555           0.057581       weak
# 3                            0.1087           0.000709    useless
# total                                         0.319083     strong

# %%
pipeline.add(Preprocessing.Step(
    input_var='StockOptionLevel',
    transformations=[
        lambda x, w=woe.dict: x.astype('str').map(w), # replace by woe value
    ],
    output_var='stock_option_level_woe',
    info=woe.iv
))

# %% [markdown]
# ### 4.28. TotalWorkingYears

# %%
plot_density(data=dataset, feature='TotalWorkingYears', target='Attrition')

# %%
transform = lambda x: pd.cut(x, bins=[-np.inf,7,37,np.inf])
feature = transform(dataset['TotalWorkingYears'])
woe.calculate(H = feature, A = y_true)
# Out:
# Attrition               Ā      А     P(Hi)   P(Hi|Ā)   P(Hi|A) posterior-odds  \
# TotalWorkingYears
# (-inf, 7.0]         391.0  131.0  0.355102  0.317113  0.552743        1.74305
# (7.0, 37.0]         841.0  104.0  0.642857  0.682076  0.438819       0.643357
# (37.0, inf]           1.0    2.0  0.002041  0.000811  0.008439        10.4051
# total              1233.0  237.0  1.000000  1.000000  1.000000
#
# Attrition         weight-of-evidence  information-value conclusion
# TotalWorkingYears
# (-inf, 7.0]                 0.555635           0.130924     medium
# (7.0, 37.0]                -0.441055           0.107290     medium
# (37.0, inf]                  2.34229           0.017867    useless
# total                                          0.256081     medium

# %%
pipeline.add(Preprocessing.Step(
    input_var='TotalWorkingYears',
    transformations=[
        transform,
        lambda x, w=woe.dict: x.astype('str').map(w), # replace by woe value
    ],
    output_var='total_working_years_bin_woe',
    info=woe.iv
))

# %% [markdown]
# ### 4.29. TrainingTimesLastYear

# %%
feature = dataset['TrainingTimesLastYear']
woe.calculate(H = feature, A = y_true)
# Out:
# Attrition                   Ā      А     P(Hi)   P(Hi|Ā)   P(Hi|A)  \
# TrainingTimesLastYear
# 0                        39.0   15.0  0.036735  0.031630  0.063291
# 1                        62.0    9.0  0.048299  0.050284  0.037975
# 2                       449.0   98.0  0.372109  0.364152  0.413502
# 3                       422.0   69.0  0.334014  0.342255  0.291139
# 4                        97.0   26.0  0.083673  0.078670  0.109705
# 5                       105.0   14.0  0.080952  0.085158  0.059072
# 6                        59.0    6.0  0.044218  0.047851  0.025316
# total                  1233.0  237.0  1.000000  1.000000  1.000000
#
# Attrition             posterior-odds weight-of-evidence  information-value  \
# TrainingTimesLastYear
# 0                            2.00097           0.693634           0.021961
# 1                           0.755206          -0.280764           0.003456
# 2                            1.13552            0.12709           0.006272
# 3                           0.850651          -0.161753           0.008268
# 4                            1.39449           0.332531           0.010320
# 5                           0.693671          -0.365758           0.009541
# 6                           0.529071          -0.636633           0.014346
# total                                                             0.074164
#
# Attrition             conclusion
# TrainingTimesLastYear
# 0                           weak
# 1                        useless
# 2                        useless
# 3                        useless
# 4                        useless
# 5                        useless
# 6                        useless
# total                       weak

# %%
pipeline.add(Preprocessing.Step(
    input_var='TrainingTimesLastYear',
    transformations=[
        lambda x, w=woe.dict: x.astype('str').map(w), # replace by woe value
    ],
    output_var='training_times_last_year_woe',
    info=woe.iv
))

# %% [markdown]
# ### 4.30. WorkLifeBalance

# %%
feature = dataset['WorkLifeBalance']
woe.calculate(H = feature, A = y_true)
# Out:
# Attrition             Ā      А     P(Hi)   P(Hi|Ā)   P(Hi|A) posterior-odds  \
# WorkLifeBalance
# 1                  55.0   25.0  0.054422  0.044607  0.105485        2.36479
# 2                 286.0   58.0  0.234014  0.231955  0.244726        1.05506
# 3                 766.0  127.0  0.607483  0.621249  0.535865       0.862561
# 4                 126.0   27.0  0.104082  0.102190  0.113924        1.11483
# total            1233.0  237.0  1.000000  1.000000  1.000000
#
# Attrition       weight-of-evidence  information-value conclusion
# WorkLifeBalance
# 1                         0.860688           0.052397       weak
# 2                        0.0535966           0.000684    useless
# 3                         -0.14785           0.012624    useless
# 4                           0.1087           0.001276    useless
# total                                        0.066981       weak

# %%
pipeline.add(Preprocessing.Step(
    input_var='WorkLifeBalance',
    transformations=[
        lambda x, w=woe.dict: x.astype('str').map(w), # replace by woe value
    ],
    output_var='work_life_balance_woe',
    info=woe.iv
))

# %% [markdown]
# ### 4.31. YearsAtCompany

# %%
plot_density(data=dataset, feature='YearsAtCompany', target='Attrition')

# %%
transform = lambda x: pd.cut(x, bins=[-np.inf,4,np.inf])
feature = transform(dataset['YearsAtCompany'])
woe.calculate(H = feature, A = y_true)
# Out:
# Attrition            Ā      А     P(Hi)   P(Hi|Ā)   P(Hi|A) posterior-odds  \
# YearsAtCompany
# (-inf, 4.0]      439.0  141.0  0.394558  0.356042  0.594937        1.67097
# (4.0, inf]       794.0   96.0  0.605442  0.643958  0.405063       0.629021
# total           1233.0  237.0  1.000000  1.000000  1.000000
#
# Attrition      weight-of-evidence  information-value conclusion
# YearsAtCompany
# (-inf, 4.0]              0.513406           0.122650     medium
# (4.0, inf]               -0.46359           0.110749     medium
# total                                       0.233399     medium

# %%
pipeline.add(Preprocessing.Step(
    input_var='YearsAtCompany',
    transformations=[
        transform,
        lambda x, w=woe.dict: x.astype('str').map(w), # replace by woe value
    ],
    output_var='years_at_company_bin_woe',
    info=woe.iv
))

# %% [markdown]
# ### 4.32. YearsInCurrentRole

# %%
plot_density(data=dataset, feature='YearsInCurrentRole', target='Attrition')

# %%
transform = lambda x: pd.cut(x, bins=[-np.inf,3,np.inf])
feature = transform(dataset['YearsInCurrentRole'])
woe.calculate(H = feature, A = y_true)
# Out:
# Attrition                Ā      А    P(Hi)   P(Hi|Ā)   P(Hi|A) posterior-odds  \
# YearsInCurrentRole
# (-inf, 3.0]          640.0  168.0  0.54966  0.519059  0.708861        1.36566
# (3.0, inf]           593.0   69.0  0.45034  0.480941  0.291139       0.605354
# total               1233.0  237.0  1.00000  1.000000  1.000000
#
# Attrition          weight-of-evidence  information-value conclusion
# YearsInCurrentRole
# (-inf, 3.0]                  0.311641           0.059150       weak
# (3.0, inf]                  -0.501943           0.095269       weak
# total                                           0.154419     medium

# %%
pipeline.add(Preprocessing.Step(
    input_var='YearsInCurrentRole',
    transformations=[
        transform,
        lambda x, w=woe.dict: x.astype('str').map(w), # replace by woe value
    ],
    output_var='years_in_current_role_bin_woe',
    info=woe.iv
))

# %% [markdown]
# ### 4.33. YearsSinceLastPromotion

# %%
plot_density(data=dataset, feature='YearsSinceLastPromotion', target='Attrition')

# %%
transform = lambda x: pd.cut(x, bins=[-np.inf,1,3,6,np.inf])
feature = transform(dataset['YearsSinceLastPromotion'])
woe.calculate(H = feature, A = y_true)
# Out:
# Attrition                     Ā      А     P(Hi)   P(Hi|Ā)   P(Hi|A)  \
# YearsSinceLastPromotion
# (-inf, 1.0]               779.0  159.0  0.638095  0.631792  0.670886
# (1.0, 3.0]                175.0   36.0  0.143537  0.141930  0.151899
# (3.0, 6.0]                125.0   13.0  0.093878  0.101379  0.054852
# (6.0, inf]                154.0   29.0  0.124490  0.124899  0.122363
# total                    1233.0  237.0  1.000000  1.000000  1.000000
#
# Attrition               posterior-odds weight-of-evidence  information-value  \
# YearsSinceLastPromotion
# (-inf, 1.0]                    1.06188          0.0600385           0.002347
# (1.0, 3.0]                     1.07024          0.0678783           0.000677
# (3.0, 6.0]                    0.541063          -0.614219           0.028577
# (6.0, inf]                    0.979698         -0.0205114           0.000052
# total                                                               0.031653
#
# Attrition               conclusion
# YearsSinceLastPromotion
# (-inf, 1.0]                useless
# (1.0, 3.0]                 useless
# (3.0, 6.0]                    weak
# (6.0, inf]                 useless
# total                         weak

# %%
pipeline.add(Preprocessing.Step(
    input_var='YearsSinceLastPromotion',
    transformations=[
        transform,
        lambda x, w=woe.dict: x.astype('str').map(w), # replace by woe value
    ],
    output_var='years_since_last_promotion_bin_woe',
    info=woe.iv
))

# %% [markdown]
# ### 4.34. YearsWithCurrManager

# %%
plot_density(data=dataset, feature='YearsWithCurrManager', target='Attrition')

# %%
transform = lambda x: pd.cut(x, bins=[-np.inf,2,np.inf])
feature = transform(dataset['YearsWithCurrManager'])
woe.calculate(H = feature, A = y_true)
# Out:
# Attrition                  Ā      А     P(Hi)   P(Hi|Ā)   P(Hi|A)  \
# YearsWithCurrManager
# (-inf, 2.0]            537.0  146.0  0.464626  0.435523  0.616034
# (2.0, inf]             696.0   91.0  0.535374  0.564477  0.383966
# total                 1233.0  237.0  1.000000  1.000000  1.000000
#
# Attrition            posterior-odds weight-of-evidence  information-value  \
# YearsWithCurrManager
# (-inf, 2.0]                 1.41447           0.346754           0.062593
# (2.0, inf]                 0.680216          -0.385345           0.069559
# total                                                            0.132152
#
# Attrition            conclusion
# YearsWithCurrManager
# (-inf, 2.0]                weak
# (2.0, inf]                 weak
# total                    medium

# %%
pipeline.add(Preprocessing.Step(
    input_var='YearsWithCurrManager',
    transformations=[
        transform,
        lambda x, w=woe.dict: x.astype('str').map(w), # replace by woe value
    ],
    output_var='years_with_curr_manager_bin_woe',
    info=woe.iv
))

# %% [markdown]
# ## 5. Feature selection

# %%
x_train = pipeline.transform(X=dataset)

# %% [markdown]
# ### 5.1. Correlation analysis

# %%
plt.figure(figsize = (12,10))
sns.heatmap(x_train.join(y_true).astype('float64').corr(), annot=True, cmap="RdYlGn", fmt=".2f")
plt.show()

# %% [markdown]
# ### 5.2. Feature impotrance by inofrmation value

# %%
pipeline.info(
    keys=['information-value','conclusion'],
    sort_by='information-value'
)
# Out:
#    conclusion                             feature  information-value
# 12     strong                        job_role_woe           0.490997
# 18     strong                        overtime_woe           0.400183
# 15     strong              monthly_income_bin_woe           0.357794
# 0      strong                         age_bin_woe           0.327640
# 21     strong              stock_option_level_woe           0.319083
# 22     medium         total_working_years_bin_woe           0.256081
# 25     medium            years_at_company_bin_woe           0.233399
# 14     medium                  marital_status_woe           0.218898
# 26     medium       years_in_current_role_bin_woe           0.154419
# 28     medium     years_with_curr_manager_bin_woe           0.132152
# 17     medium            num_companies_worked_woe           0.130967
# 11     medium                   job_involment_woe           0.125946
# 1      medium                 business_travel_woe           0.120868
# 8        weak         enviroment_satisfaction_woe           0.099886
# 13       weak                job_satisfaction_woe           0.087689
# 23       weak        training_times_last_year_woe           0.074164
# 6        weak                 education_field_woe           0.072779
# 24       weak               work_life_balance_woe           0.066981
# 4        weak          distance_from_home_bin_woe           0.052690
# 3        weak                      department_woe           0.052175
# 2        weak                  daily_rate_bin_woe           0.047185
# 27       weak  years_since_last_promotion_bin_woe           0.031653
# 20       weak       relationship_satisfaction_woe           0.024532
# 10       weak                 hourly_rate_bin_woe           0.020774
# 19    useless         percent_salary_hike_bin_woe           0.017224
# 5     useless                       education_woe           0.016505
# 16    useless                monthly_rate_bin_woe           0.009298
# 7     useless             employee_number_bin_woe           0.007257
# 9     useless                          gender_woe           0.006496

# %% [markdown]
# ### 5.3. Single variable test by model

# %%
single_feature_test = pd.DataFrame()

for col in x_train.columns:
    i = x_train[col].values.reshape(-1, 1)
    logreg = LogisticRegression()
    logreg.fit(i, y_true)
    single_feature_test = single_feature_test.append({'feature':col, 'score':round(logreg.score(i, y_true) * 100, 2)}, ignore_index=True)

single_feature_test.sort_values('score', ascending=False)
# Out:
#                                feature  score
# 0                          age_bin_woe  84.15
# 22         total_working_years_bin_woe  83.95
# 15              monthly_income_bin_woe  83.88
# 27  years_since_last_promotion_bin_woe  83.88
# 26       years_in_current_role_bin_woe  83.88
# 25            years_at_company_bin_woe  83.88
# 24               work_life_balance_woe  83.88
# 23        training_times_last_year_woe  83.88
# 21              stock_option_level_woe  83.88
# 20       relationship_satisfaction_woe  83.88
# 19         percent_salary_hike_bin_woe  83.88
# 18                        overtime_woe  83.88
# 17            num_companies_worked_woe  83.88
# 16                monthly_rate_bin_woe  83.88
# 14                  marital_status_woe  83.88
# 1                  business_travel_woe  83.88
# 13                job_satisfaction_woe  83.88
# 12                        job_role_woe  83.88
# 11                   job_involment_woe  83.88
# 10                 hourly_rate_bin_woe  83.88
# 9                           gender_woe  83.88
# 8          enviroment_satisfaction_woe  83.88
# 7              employee_number_bin_woe  83.88
# 6                  education_field_woe  83.88
# 5                        education_woe  83.88
# 4           distance_from_home_bin_woe  83.88
# 3                       department_woe  83.88
# 2                   daily_rate_bin_woe  83.88
# 28     years_with_curr_manager_bin_woe  83.88

# %% [markdown]
# ### 5.4 Filter

# %% [markdown]
# Remove all steps with feature iv less 0.1

# %%
for key in pipeline._items.copy():
    i = pipeline._items[key].info.get('information-value')
    if i < 0.1:
        print(round(i,4), key)
        del pipeline._items[key]
# Out:
# 0.0472 daily_rate_bin_woe
# 0.0522 department_woe
# 0.0527 distance_from_home_bin_woe
# 0.0165 education_woe
# 0.0728 education_field_woe
# 0.0073 employee_number_bin_woe
# 0.0999 enviroment_satisfaction_woe
# 0.0065 gender_woe
# 0.0208 hourly_rate_bin_woe
# 0.0877 job_satisfaction_woe
# 0.0093 monthly_rate_bin_woe
# 0.0172 percent_salary_hike_bin_woe
# 0.0245 relationship_satisfaction_woe
# 0.0742 training_times_last_year_woe
# 0.067 work_life_balance_woe
# 0.0317 years_since_last_promotion_bin_woe

# %%
x_train = pipeline.transform(X=dataset)

# %% [markdown]
# ## 5. Modeling

# %%
x_train.isnull().sum().sort_values(ascending=False).compress(lambda x: x>0)
# Out:
# Series([], dtype: int64)

# %% [markdown]
# ### 5.1. Base model (Logistic Regression)

# %%
model = LogisticRegression()
model.fit(x_train, y_true)
y_pred_proba = pd.Series(model.predict_proba(x_train)[:,1], name = 'y_pred_proba')
print('accuracy with 0.5 threshold: {}'.format(round(model.score(x_train, y_true) * 100, 2)))
# Out:
# accuracy with 0.5 threshold: 86.8

# %% [markdown]
# Choose custom threshold if distribution is skewed or if the task requires it

# %%
plot_model_summary(y_true, y_pred_proba, threshold=0.2,  class_labels = ['retention','attrition'])

# %%
coeff_df = pd.DataFrame(x_train.columns)
coeff_df.columns = ['feature']
coeff_df["coef"] = pd.Series(model.coef_[0])
coeff_df["odds"] = pd.Series(model.coef_[0]).apply(np.exp)
coeff_df.sort_values(by='odds', ascending=False)
# Out:
#                             feature      coef      odds
# 7                      overtime_woe  1.174380  3.236136
# 1               business_travel_woe  1.060361  2.887412
# 2                 job_involment_woe  1.059768  2.885700
# 6          num_companies_worked_woe  0.870803  2.388828
# 8            stock_option_level_woe  0.844680  2.327234
# 3                      job_role_woe  0.674628  1.963302
# 10         years_at_company_bin_woe  0.549285  1.732015
# 0                       age_bin_woe  0.487680  1.628534
# 5            monthly_income_bin_woe  0.301616  1.352041
# 4                marital_status_woe  0.103559  1.109111
# 11    years_in_current_role_bin_woe  0.078640  1.081815
# 9       total_working_years_bin_woe  0.062411  1.064399
# 12  years_with_curr_manager_bin_woe -0.213503  0.807750

# %% [markdown]
# ### 5.2. Models benchmark

# %%
models = { 
        'logreg':LogisticRegression(),
        'random-forest': RandomForestClassifier(n_estimators=100),
        'svc': SVC(),
        'svc-linear': LinearSVC(),
        'knn': KNeighborsClassifier(n_neighbors = 6),
        'gradient-boosting': GradientBoostingClassifier(),
        'decission-tree': DecisionTreeClassifier(),
        'naive-bayes': GaussianNB(),
        'perceptron': Perceptron(max_iter=100),
        'sgd':SGDClassifier(max_iter=100),
        'lgmb': LGBMClassifier(),
    }
model_benchmark(x_train.astype('float64'),y_true,models).sort_values(by='cross-score', ascending=False).head(20)
# Out:
#                          model  train-score      cross-score              auc
# 0           LogisticRegression        86.80  0.865 (+-0.011)  0.820 (+-0.022)
# 9                SGDClassifier        85.78  0.858 (+-0.014)  0.782 (+-0.031)
# 3                    LinearSVC        86.87  0.857 (+-0.007)  0.818 (+-0.021)
# 5   GradientBoostingClassifier        90.34  0.854 (+-0.016)  0.791 (+-0.022)
# 4         KNeighborsClassifier        87.21  0.852 (+-0.010)  0.728 (+-0.007)
# 2                          SVC        85.92  0.850 (+-0.003)  0.782 (+-0.023)
# 1       RandomForestClassifier        99.18  0.848 (+-0.007)  0.769 (+-0.009)
# 10              LGBMClassifier        96.33  0.845 (+-0.020)  0.784 (+-0.023)
# 7                   GaussianNB        81.63  0.814 (+-0.020)  0.788 (+-0.018)
# 8                   Perceptron        83.47  0.799 (+-0.034)  0.751 (+-0.040)
# 6       DecisionTreeClassifier        99.18  0.797 (+-0.023)  0.629 (+-0.022)
